# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import xlrd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
svod_world_df = pd.read_excel('../data/0_svod_worldwide.xlsx', header=None)
svod_world_df
# Out:
#     0                                                1         2         3   \
# 0  NaN                           Revenue in million US$   2017.00   2018.00
# 1  NaN                                            Total  20842.13  22535.99
# 2  NaN                        Revenue Growth in percent   2017.00   2018.00
# 3  NaN                                            Total       NaN      8.13
# 4  NaN                                Users in millions   2017.00   2018.00
# 5  NaN                                            Total    972.36   1019.00
# 6  NaN                      Penetration Rate in percent   2017.00   2018.00
# 7  NaN                                            Total     13.48     13.98
# 8  NaN                                      ARPU in US$   2017.00   2018.00
# 9  NaN                                            Total     21.43     22.12
# 10 NaN                          Users by age in percent   2017.00   2018.00
# ...

# %%
#for multiple sheets:

#video_streaming_df = pd.ExcelFile('../data/0_svod_market_landscape.xls')
#df1 = pd.read_excel(xls, 'Sheet1')
#df2 = pd.read_excel(xls, 'Sheet2')
